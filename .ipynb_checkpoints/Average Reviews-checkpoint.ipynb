# %%
from arcgis.gis import GIS
from IPython.display import display

# %%
gis = GIS('https://spt-eaglegis.maps.arcgis.com', 'spt_rjc', '7Boot650')

# %%
locations = 'd3c8af91ee204b178def4e71be54fc9e'
reviews = '391787af300644789e74c1bf9ee6f772'

# %%
get_locations = gis.content.get(locations)
lyr_locations = get_locations.layers[1]
set_locations = lyr_locations.query()
fet_locations = set_locations.features

# %%
get_reviews = gis.content.get(reviews)
lyr_reviews = get_reviews.layers[0]
set_reviews = lyr_reviews.query()
ftr_reviews = set_reviews.features

# %%
allReviews = []

for x in ftr_reviews:
    
    dictionary = {}
    
    dictionary['location'] = x.attributes['actual']
    dictionary['overall'] = x.attributes['overall_review']
    dictionary['value'] = x.attributes['value']
    dictionary['presentation'] = x.attributes['presentation']
    dictionary['service'] = x.attributes['service']
    dictionary['creativity'] = x.attributes['creativity']
    dictionary['pun'] = x.attributes['pun_value']
    
    allReviews.append(dictionary)

# %%
for x in ftr_reviews:
    
    location = x.attributes['actual']
    
    
    
    overall = int(x.attributes['overall_review'])
    value = int(x.attributes['value'])
    presentation = int(x.attributes['presentation'])
    service = int(x.attributes['service'])
    creativity = int(x.attributes['creativity'])
    pun = int(x.attributes['pun_value'])

# %%
data = x.attributes.get("actual", "")
data
# Out:
# 'Aston Norwood Cafe'

# %%
allReviews = []
actualList = []
n = 0

for x in ftr_reviews:
    
    actual = x.attributes['actual']
    
    overallList = []
    valueList = []
    presentationList = []
    serviceList = []
    creativityList = []
    punList = []    
    
    if actual in actualList:
    
        overallList.append(x.attributes['overall_review'])
        print (overallList)
        valueList.append(x.attributes['value'])
        presentationList.append(x.attributes['presentation'])
        serviceList.append(x.attributes['service'])
        creativityList.append(x.attributes['creativity'])
        punList.append(x.attributes['pun_value'])
        
    else:
        
        actualList.append(actual)
        
        overallList = []
        valueList = []
        presentationList = []
        serviceList = []
        creativityList = []
        punList = []   
        
        overallList.append(x.attributes['overall_review'])
        valueList.append(x.attributes['value'])
        presentationList.append(x.attributes['presentation'])
        serviceList.append(x.attributes['service'])
        creativityList.append(x.attributes['creativity'])
        punList.append(x.attributes['pun_value'])
  


    print (actual)
    print (overallList)
    print (valueList)
    print (presentationList)
    print (serviceList)
    print (creativityList)
    print (punList)
# Out:
# Cicio Cacio Osteria
# ['6']
# ['8']
# ['3']
# ['9']
# ['7']
# ['3']
# Baobab Cafe
# ['9']
# ['6']
# ['8']
# ['6']
# ['4']
# ['9']
# HI
# ['3']
# Baobab Cafe
# ['3']
# [None]
# [None]
# [None]
# [None]
# [None]
# HI
# ['7']
# Baobab Cafe
# ['7']
# [None]
# [None]
# [None]
# [None]
# [None]
# HI
# ['10']
# Baobab Cafe
# ['10']
# [None]
# [None]
# [None]
# [None]
# [None]
# HI
# ['7']
# Baobab Cafe
# ['7']
# ['7']
# ['8']
# ['9']
# ['8']
# ['9']
# HI
# ['10']
# Baobab Cafe
# ['10']
# [None]
# [None]
# [None]
# [None]
# [None]
# HI
# ['5']
# Baobab Cafe
# ['5']
# [None]
# [None]
# [None]
# [None]
# [None]
# HI
# ['9']
# Baobab Cafe
# ['9']
# [None]
# [None]
# [None]
# [None]
# [None]
# HI
# ['8']
# Baobab Cafe
# ['8']
# [None]
# [None]
# [None]
# [None]
# [None]
# Panhead Custom Ales
# ['9']
# [None]
# [None]
# [None]
# [None]
# [None]
# HI
# ['9']
# Panhead Custom Ales
# ['9']
# ['6']
# ['9']
# ['8']
# ['10']
# ['6']
# HI
# ['4']
# Panhead Custom Ales
# ['4']
# ['8']
# ['5']
# ['9']
# ...

# %%
overallList
# Out:
# ['1']

# %%
allReviews
# Out:
# [{'location': 'Cicio Cacio Osteria',
#   'overall': '6',
#   'value': '8',
#   'presentation': '3',
#   'service': '9',
#   'creativity': '7',
#   'pun': '3'},
#  {'location': 'Baobab Cafe',
#   'overall': '9',
#   'value': '6',
#   'presentation': '8',
#   'service': '6',
#   'creativity': '4',
#   'pun': '9'},
#  {'location': 'Baobab Cafe',
#   'overall': '3',
#   'value': None,
#   'presentation': None,
#   'service': None,
#   'creativity': None,
#   'pun': None},
#  {'location': 'Baobab Cafe',
#   'overall': '7',
#   'value': None,
#   'presentation': None,
#   'service': None,
#   'creativity': None,
#   'pun': None},
#  {'location': 'Baobab Cafe',
#   'overall': '10',
#   'value': None,
#   'presentation': None,
#   'service': None,
#   'creativity': None,
#   'pun': None},
#  {'location': 'Baobab Cafe',
#   'overall': '7',
#   'value': '7',
#   'presentation': '8',
#   'service': '9',
#   'creativity': '8',
#   'pun': '9'},
#  {'location': 'Baobab Cafe',
#   'overall': '10',
# ...
